# %%
pip install --upgrade jinja2
# Out:
# Requirement already satisfied: jinja2 in /Users/jw2379/opt/anaconda3/lib/python3.9/site-packages (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jw2379/opt/anaconda3/lib/python3.9/site-packages (from jinja2) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PairsTradingRollingOLS import *
from PairsTradingBacktest import *
from IPython.display import display, HTML
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
window = 30
df_prices_test = pd.read_csv("data/etfs/df_prices_test.csv", index_col=0)
df_prices_test.index = pd.to_datetime(df_prices_test.index)
prices = df_prices_test

index = prices.index.strftime('%Y-%m-%d')
# S&P500 ETF
# sp500 = yf.download('SPY', start=index[window-1], end=index[-1])['Adj Close']
sp500 = yf.download('^GSPC', start=index[2*window-2], end=index[-1])['Adj Close']
sp500_nav = sp500 / sp500.iloc[0]
sp500_drawdowns = calculate_drawdown(sp500_nav)

# US Treasury
USTreasury = yf.download('^TNX', start=index[2*window-2], end=index[-1])['Adj Close']
USTreasury_daily_returns = (USTreasury / 100) / 252
USTreasury_nav = pd.Series(index=USTreasury.index)
USTreasury_nav.iloc[0] = 1
for i in range(1, len(USTreasury_daily_returns)):
    USTreasury_nav.iloc[i] = USTreasury_nav.iloc[i - 1] * (1 + USTreasury_daily_returns.iloc[i])
USTreasury_drawdowns = calculate_drawdown(USTreasury_nav)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
etfs_list = [ ('AMJ', 'AMU'), ('CORN', 'WEAT'), ('RING', 'SGDM'), ('GLD', 'OUNZ'), ('GLD', 'SGOL'), ('OUNZ', 'SGOL')]
# etfs_list = [('RING', 'SGDM'), ('AMJ', 'AMU'), ('CORN', 'WEAT'),('GLD', 'OUNZ'), ('GLD', 'SGOL'), ('OUNZ', 'SGOL')]
# etfs_list = [ ('AMJ', 'CORN'), ('AMU', 'WEAT'), ('RING', 'GLD'), ('SGDM', 'CORN'), ('AMJ', 'OUNZ'), ('CORN', 'SGOL')]
pnl_dict = {}
nav_dict = {}
drawdowns_dict = {}


for etfs in etfs_list:
    print("\n")
    display(HTML(f'<p style="font-size: 30px;">{etfs}</p>'))
    print("\n")
    draw_date_coloured_scatterplot(etfs, prices)
    beta_0, beta_1 = calc_slope_intercept_rollingOLS(etfs, prices, window)
    draw_slope_intercept_changes_rollingOLS(prices.iloc[window-1:], beta_0.iloc[window-1:], beta_1.iloc[window-1:])
    
    # Run the backtest
    context = Context()
    initialize(context, etfs, prices, window)
    
    ### DEBUG
    context.etf1_price_prev = df_prices_test[etfs[0]].iloc[0]
    context.etf2_price_prev = df_prices_test[etfs[1]].iloc[0]
    
    for i in range(2*window-2, len(df_prices_test) - 1):
        handle_data(context, prices.iloc[2*window-2: i+1], etfs)
    
    # forecast error
    errors = context.zscores
    
    # forecast standard deviation
    stds = context.stds
    neg_stds = [-x for x in stds]
    
    # pnl
    pnl = context.pnl_history
    pnl_dict[etfs] = pnl
    
    # NAV
    nav = context.nav_history
    nav_dict[etfs] = nav
    
    # daily returns
    daily_returns = context.daily_returns
    
    # cumulative returns
    cum_returns = np.cumprod(1 + np.array(context.daily_returns)) - 1
    
    #drawdown
    ### DEBUG
    highwatermarks = np.maximum.accumulate(nav)
    drawdowns = (nav - highwatermarks) / highwatermarks
    drawdowns_dict[etfs] = drawdowns
    
    # plot figures
    plot_spread_rollingOLS(prices, errors, stds, neg_stds, window)
    plot_nav_sp500_rollingOLS(prices, nav, sp500_nav, USTreasury_nav, window)
#     plot_cum_returns(prices, cum_returns)
#     plot_drawdown(prices, drawdowns)
    display(HTML(pnl_metrics(daily_returns, sp500_nav, sp500_drawdowns, USTreasury_nav, USTreasury_drawdowns).style.set_table_attributes('style="font-size: 16px;"').render()))
    print('\n\n\n')
# Out:
# <p style="font-size: 30px;">('AMJ', 'AMU')</p>
# <style type="text/css">
# </style>
# <table id="T_de01b" style="font-size: 16px;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de01b_level0_col0" class="col_heading level0 col0" >KF Pairs Trading</th>
#       <th id="T_de01b_level0_col1" class="col_heading level0 col1" >S&P 500</th>
#       <th id="T_de01b_level0_col2" class="col_heading level0 col2" >10 Year US Treasury</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de01b_level0_row0" class="row_heading level0 row0" >Annualized Return</th>
#       <td id="T_de01b_row0_col0" class="data row0 col0" >0.011123</td>
#       <td id="T_de01b_row0_col1" class="data row0 col1" >0.129221</td>
#       <td id="T_de01b_row0_col2" class="data row0 col2" >0.024943</td>
#     </tr>
#     <tr>
#       <th id="T_de01b_level0_row1" class="row_heading level0 row1" >Annualized Volatility</th>
#       <td id="T_de01b_row1_col0" class="data row1 col0" >0.020789</td>
#       <td id="T_de01b_row1_col1" class="data row1 col1" >0.141725</td>
#       <td id="T_de01b_row1_col2" class="data row1 col2" >0.000324</td>
#     </tr>
#     <tr>
#       <th id="T_de01b_level0_row2" class="row_heading level0 row2" >Sharpe Ratio</th>
#       <td id="T_de01b_row2_col0" class="data row2 col0" >-0.426988</td>
#       <td id="T_de01b_row2_col1" class="data row2 col1" >0.770656</td>
#       <td id="T_de01b_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_de01b_level0_row3" class="row_heading level0 row3" >Max Drawdown</th>
#       <td id="T_de01b_row3_col0" class="data row3 col0" >-0.020952</td>
#       <td id="T_de01b_row3_col1" class="data row3 col1" >-0.197782</td>
#       <td id="T_de01b_row3_col2" class="data row3 col2" >-0.000000</td>
#     </tr>
#   </tbody>
# </table>
# <p style="font-size: 30px;">('CORN', 'WEAT')</p>
# <style type="text/css">
# </style>
# <table id="T_f38cc" style="font-size: 16px;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f38cc_level0_col0" class="col_heading level0 col0" >KF Pairs Trading</th>
#       <th id="T_f38cc_level0_col1" class="col_heading level0 col1" >S&P 500</th>
#       <th id="T_f38cc_level0_col2" class="col_heading level0 col2" >10 Year US Treasury</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f38cc_level0_row0" class="row_heading level0 row0" >Annualized Return</th>
#       <td id="T_f38cc_row0_col0" class="data row0 col0" >0.049770</td>
#       <td id="T_f38cc_row0_col1" class="data row0 col1" >0.129221</td>
#       <td id="T_f38cc_row0_col2" class="data row0 col2" >0.024943</td>
#     </tr>
#     <tr>
#       <th id="T_f38cc_level0_row1" class="row_heading level0 row1" >Annualized Volatility</th>
#       <td id="T_f38cc_row1_col0" class="data row1 col0" >0.058527</td>
#       <td id="T_f38cc_row1_col1" class="data row1 col1" >0.141725</td>
#       <td id="T_f38cc_row1_col2" class="data row1 col2" >0.000324</td>
#     </tr>
#     <tr>
#       <th id="T_f38cc_level0_row2" class="row_heading level0 row2" >Sharpe Ratio</th>
#       <td id="T_f38cc_row2_col0" class="data row2 col0" >0.508656</td>
#       <td id="T_f38cc_row2_col1" class="data row2 col1" >0.770656</td>
#       <td id="T_f38cc_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f38cc_level0_row3" class="row_heading level0 row3" >Max Drawdown</th>
#       <td id="T_f38cc_row3_col0" class="data row3 col0" >-0.066314</td>
#       <td id="T_f38cc_row3_col1" class="data row3 col1" >-0.197782</td>
#       <td id="T_f38cc_row3_col2" class="data row3 col2" >-0.000000</td>
#     </tr>
#   </tbody>
# </table>
# <p style="font-size: 30px;">('RING', 'SGDM')</p>
# <style type="text/css">
# </style>
# <table id="T_c1284" style="font-size: 16px;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1284_level0_col0" class="col_heading level0 col0" >KF Pairs Trading</th>
#       <th id="T_c1284_level0_col1" class="col_heading level0 col1" >S&P 500</th>
#       <th id="T_c1284_level0_col2" class="col_heading level0 col2" >10 Year US Treasury</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1284_level0_row0" class="row_heading level0 row0" >Annualized Return</th>
#       <td id="T_c1284_row0_col0" class="data row0 col0" >-0.000468</td>
#       <td id="T_c1284_row0_col1" class="data row0 col1" >0.129221</td>
#       <td id="T_c1284_row0_col2" class="data row0 col2" >0.024943</td>
#     </tr>
#     <tr>
#       <th id="T_c1284_level0_row1" class="row_heading level0 row1" >Annualized Volatility</th>
#       <td id="T_c1284_row1_col0" class="data row1 col0" >0.028582</td>
#       <td id="T_c1284_row1_col1" class="data row1 col1" >0.141725</td>
#       <td id="T_c1284_row1_col2" class="data row1 col2" >0.000324</td>
#     </tr>
#     <tr>
#       <th id="T_c1284_level0_row2" class="row_heading level0 row2" >Sharpe Ratio</th>
#       <td id="T_c1284_row2_col0" class="data row2 col0" >-0.716131</td>
#       <td id="T_c1284_row2_col1" class="data row2 col1" >0.770656</td>
#       <td id="T_c1284_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c1284_level0_row3" class="row_heading level0 row3" >Max Drawdown</th>
#       <td id="T_c1284_row3_col0" class="data row3 col0" >-0.032834</td>
#       <td id="T_c1284_row3_col1" class="data row3 col1" >-0.197782</td>
#       <td id="T_c1284_row3_col2" class="data row3 col2" >-0.000000</td>
#     </tr>
#   </tbody>
# </table>
# <p style="font-size: 30px;">('GLD', 'OUNZ')</p>
# <style type="text/css">
# </style>
# <table id="T_f0940" style="font-size: 16px;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0940_level0_col0" class="col_heading level0 col0" >KF Pairs Trading</th>
#       <th id="T_f0940_level0_col1" class="col_heading level0 col1" >S&P 500</th>
#       <th id="T_f0940_level0_col2" class="col_heading level0 col2" >10 Year US Treasury</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0940_level0_row0" class="row_heading level0 row0" >Annualized Return</th>
#       <td id="T_f0940_row0_col0" class="data row0 col0" >-0.008151</td>
#       <td id="T_f0940_row0_col1" class="data row0 col1" >0.129221</td>
#       <td id="T_f0940_row0_col2" class="data row0 col2" >0.024943</td>
#     </tr>
#     <tr>
#       <th id="T_f0940_level0_row1" class="row_heading level0 row1" >Annualized Volatility</th>
#       <td id="T_f0940_row1_col0" class="data row1 col0" >0.012298</td>
#       <td id="T_f0940_row1_col1" class="data row1 col1" >0.141725</td>
#       <td id="T_f0940_row1_col2" class="data row1 col2" >0.000324</td>
#     </tr>
#     <tr>
#       <th id="T_f0940_level0_row2" class="row_heading level0 row2" >Sharpe Ratio</th>
#       <td id="T_f0940_row2_col0" class="data row2 col0" >-2.289043</td>
#       <td id="T_f0940_row2_col1" class="data row2 col1" >0.770656</td>
#       <td id="T_f0940_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f0940_level0_row3" class="row_heading level0 row3" >Max Drawdown</th>
#       <td id="T_f0940_row3_col0" class="data row3 col0" >-0.018456</td>
#       <td id="T_f0940_row3_col1" class="data row3 col1" >-0.197782</td>
#       <td id="T_f0940_row3_col2" class="data row3 col2" >-0.000000</td>
#     </tr>
#   </tbody>
# </table>
# <p style="font-size: 30px;">('GLD', 'SGOL')</p>
# <style type="text/css">
# </style>
# <table id="T_5e65b" style="font-size: 16px;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e65b_level0_col0" class="col_heading level0 col0" >KF Pairs Trading</th>
#       <th id="T_5e65b_level0_col1" class="col_heading level0 col1" >S&P 500</th>
#       <th id="T_5e65b_level0_col2" class="col_heading level0 col2" >10 Year US Treasury</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e65b_level0_row0" class="row_heading level0 row0" >Annualized Return</th>
#       <td id="T_5e65b_row0_col0" class="data row0 col0" >0.007571</td>
#       <td id="T_5e65b_row0_col1" class="data row0 col1" >0.129221</td>
#       <td id="T_5e65b_row0_col2" class="data row0 col2" >0.024943</td>
#     </tr>
#     <tr>
#       <th id="T_5e65b_level0_row1" class="row_heading level0 row1" >Annualized Volatility</th>
#       <td id="T_5e65b_row1_col0" class="data row1 col0" >0.005470</td>
#       <td id="T_5e65b_row1_col1" class="data row1 col1" >0.141725</td>
#       <td id="T_5e65b_row1_col2" class="data row1 col2" >0.000324</td>
#     </tr>
#     <tr>
#       <th id="T_5e65b_level0_row2" class="row_heading level0 row2" >Sharpe Ratio</th>
#       <td id="T_5e65b_row2_col0" class="data row2 col0" >-2.272122</td>
#       <td id="T_5e65b_row2_col1" class="data row2 col1" >0.770656</td>
#       <td id="T_5e65b_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_5e65b_level0_row3" class="row_heading level0 row3" >Max Drawdown</th>
#       <td id="T_5e65b_row3_col0" class="data row3 col0" >-0.003864</td>
#       <td id="T_5e65b_row3_col1" class="data row3 col1" >-0.197782</td>
#       <td id="T_5e65b_row3_col2" class="data row3 col2" >-0.000000</td>
#     </tr>
#   </tbody>
# </table>
# <p style="font-size: 30px;">('OUNZ', 'SGOL')</p>
# <style type="text/css">
# </style>
# <table id="T_06766" style="font-size: 16px;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06766_level0_col0" class="col_heading level0 col0" >KF Pairs Trading</th>
#       <th id="T_06766_level0_col1" class="col_heading level0 col1" >S&P 500</th>
#       <th id="T_06766_level0_col2" class="col_heading level0 col2" >10 Year US Treasury</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06766_level0_row0" class="row_heading level0 row0" >Annualized Return</th>
#       <td id="T_06766_row0_col0" class="data row0 col0" >0.017185</td>
#       <td id="T_06766_row0_col1" class="data row0 col1" >0.129221</td>
#       <td id="T_06766_row0_col2" class="data row0 col2" >0.024943</td>
#     </tr>
#     <tr>
#       <th id="T_06766_level0_row1" class="row_heading level0 row1" >Annualized Volatility</th>
#       <td id="T_06766_row1_col0" class="data row1 col0" >0.012748</td>
#       <td id="T_06766_row1_col1" class="data row1 col1" >0.141725</td>
#       <td id="T_06766_row1_col2" class="data row1 col2" >0.000324</td>
#     </tr>
#     <tr>
#       <th id="T_06766_level0_row2" class="row_heading level0 row2" >Sharpe Ratio</th>
#       <td id="T_06766_row2_col0" class="data row2 col0" >-0.220791</td>
#       <td id="T_06766_row2_col1" class="data row2 col1" >0.770656</td>
#       <td id="T_06766_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_06766_level0_row3" class="row_heading level0 row3" >Max Drawdown</th>
#       <td id="T_06766_row3_col0" class="data row3 col0" >-0.005245</td>
#       <td id="T_06766_row3_col1" class="data row3 col1" >-0.197782</td>
#       <td id="T_06766_row3_col2" class="data row3 col2" >-0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(figsize=(30, 15))
colors = [ '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#1f77b4', '#ff7f0e']

for idx, (key, value) in enumerate(nav_dict.items()):
    ax.plot(prices.index[2*window-2:], value, label=key, color=colors[idx % len(colors)], linestyle='-', linewidth=2)
ax.set_title('Unit NAV', fontsize=25)
ax.set_xlabel('Time', fontsize=20)
ax.set_ylabel('Unit NAV', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.grid(True, linestyle='--', alpha=0.5)
ax.legend(fontsize=20, loc='best')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(35, 10))
colors = ['#2ca02c', '#d62728','#1f77b4', '#ff7f0e', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

for idx, (key, value) in enumerate(drawdowns_dict.items()):
    ax.plot(prices.index[2*window-2:], value, label=key, color=colors[idx % len(colors)], linestyle='-', linewidth=2)
    ax.fill_between(prices.index[2*window-2:], value, 0, color=colors[idx % len(colors)], alpha=0.2)
ax.set_title('Drawdown', fontsize=25)
ax.set_xlabel('Time', fontsize=20)
ax.set_ylabel('Drawdown', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.grid(True, linestyle='--', alpha=0.5)
ax.legend(fontsize=20, loc='best')
plt.show()

# %% [markdown]
# # Build a equal-weight portfolio

# %%
portfolio_nav = [0] * len(next(iter(nav_dict.values())))

# portfolio NAV
num_assets = len(nav_dict)
for key, nav_list in nav_dict.items():
    for i, nav in enumerate(nav_list):
        portfolio_nav[i] += nav / num_assets

# %%
plot_nav_sp500_rollingOLS(prices, portfolio_nav, sp500_nav, USTreasury_nav, window)

# %%
#drawdown
portfolio_drawdown = calculate_drawdown(portfolio_nav)
plot_drawdown_sp500_rollingOLS(prices, portfolio_drawdown, sp500_drawdowns,USTreasury_drawdowns, window)

# %%
portfolio_daily_returns = calculate_daily_returns(portfolio_nav)
display(HTML(pnl_metrics(portfolio_daily_returns, sp500_nav, sp500_drawdowns, USTreasury_nav, USTreasury_drawdowns).style.set_table_attributes('style="font-size: 16px;"').render()))
# Out:
# <style type="text/css">
# </style>
# <table id="T_f7dd4" style="font-size: 16px;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7dd4_level0_col0" class="col_heading level0 col0" >KF Pairs Trading</th>
#       <th id="T_f7dd4_level0_col1" class="col_heading level0 col1" >S&P 500</th>
#       <th id="T_f7dd4_level0_col2" class="col_heading level0 col2" >10 Year US Treasury</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7dd4_level0_row0" class="row_heading level0 row0" >Annualized Return</th>
#       <td id="T_f7dd4_row0_col0" class="data row0 col0" >0.012775</td>
#       <td id="T_f7dd4_row0_col1" class="data row0 col1" >0.129221</td>
#       <td id="T_f7dd4_row0_col2" class="data row0 col2" >0.024943</td>
#     </tr>
#     <tr>
#       <th id="T_f7dd4_level0_row1" class="row_heading level0 row1" >Annualized Volatility</th>
#       <td id="T_f7dd4_row1_col0" class="data row1 col0" >0.011870</td>
#       <td id="T_f7dd4_row1_col1" class="data row1 col1" >0.141725</td>
#       <td id="T_f7dd4_row1_col2" class="data row1 col2" >0.000324</td>
#     </tr>
#     <tr>
#       <th id="T_f7dd4_level0_row2" class="row_heading level0 row2" >Sharpe Ratio</th>
#       <td id="T_f7dd4_row2_col0" class="data row2 col0" >-0.608718</td>
#       <td id="T_f7dd4_row2_col1" class="data row2 col1" >0.770656</td>
#       <td id="T_f7dd4_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f7dd4_level0_row3" class="row_heading level0 row3" >Max Drawdown</th>
#       <td id="T_f7dd4_row3_col0" class="data row3 col0" >-0.008904</td>
#       <td id="T_f7dd4_row3_col1" class="data row3 col1" >-0.197782</td>
#       <td id="T_f7dd4_row3_col2" class="data row3 col2" >-0.000000</td>
#     </tr>
#   </tbody>
# </table>
